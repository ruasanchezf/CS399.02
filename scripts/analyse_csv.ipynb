# %% [markdown]
# Start here if loading the file:

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("../csv_files/test.csv", encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/6l/7gh6dn014p753wk_9mhq2ns80000gn/T/ipykernel_62182/369353442.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 data = pd.read_csv("../csv-files/test.csv", encoding='latin-1')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
source = data["Destination"].value_counts().idxmax()
source
# Out:
# '10.133.2.187'

# %%
data.iloc[0]
# Out:
# No.                                      1
# Time                                   0.0
# Source                        10.133.2.187
# Destination                 17.248.139.230
# Protocol                               UDP
# Length                                  84
# Info           58755  >  https(443) Len=56
# Name: 0, dtype: object

# %%
data["Destination"].value_counts().drop(source).plot.pie()
# Out:
# <AxesSubplot:ylabel='Destination'>

# %%
data["Destination"].value_counts().drop(source)[:10]
# Out:
# scontent-msp1-1.cdninstagram.com        997
# ff02::fb                                252
# eip-tata.video.twimg.com.akahost.net    181
# edge-web.dual-gslb.spotify.com          137
# ns1.its.carleton.edu                    119
# inbox.google.com                        107
# tpop-api.twitter.com                    103
# cs45.wac.edgecastcdn.net                 72
# e69896.dscapi6.akamaiedge.net            65
# 17.248.139.202                           64
# Name: Destination, dtype: int64

# %%
data["Source"].value_counts().drop(source).plot.pie()
# Out:
# <AxesSubplot:ylabel='Source'>

# %%
data["Protocol"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Protocol'>

# %%
data["Length"].groupby(data["Protocol"]).sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Protocol'>

# %%
data["Length"].groupby(data["Protocol"]).sum().drop('QUIC').plot.bar()
# Out:
# <AxesSubplot:xlabel='Protocol'>

# %%
data["Length"].groupby(data["Destination"]).mean().drop(source)[:5].plot.bar()
# Out:
# <AxesSubplot:xlabel='Destination'>
